# %%
# %matplotlib notebook
# %reset -f


import pandas as pd
import numpy as np
from scipy.stats import norm, probplot
import statsmodels.api as sm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from sklearn import preprocessing,metrics
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

### Função utilitária para fazer a regressão com constante adicionada
def regress(X,Y):
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    return results

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Fonte:

df = pd.read_excel("jogo.xlsx")

# %% [markdown]
# # Limpeza da Base de Dados

# %%
deletar = df.loc[((df.Global_Sales.fillna(0)) == 0) & ((df.Total_Shipped.fillna(0)) == 0)]
a = deletar.index
dados = df.drop(a)

# %%
dados["Sales"] = dados["Global_Sales"].fillna(0) + dados["Total_Shipped"].fillna(0)

# %%
dados = dados.drop(columns = ["Global_Sales","Total_Shipped","url","status","img_url","NA_Sales" ,"PAL_Sales","JP_Sales" ,"Other_Sales","VGChartz_Score"])

# %%
dados = dados.fillna(0)

# %%
dados = dados.loc[((dados.Sales != 0 ) & (dados.Critic_Score != 0))]
data = dados

# %% [markdown]
# # Separação das variaveis e primeiras regressões lineares

# %%
from sklearn.model_selection import train_test_split
dados_sales,teste, y_train, y_test = train_test_split(data,data.Sales, test_size=0.25, random_state=RANDOM_SEED)


qualitativas = ['Genre', 'ESRB_Rating', 'Platform',
       'Publisher', 'Developer']
quantitativas = ['Rank', 'Critic_Score',
       'User_Score','Vgchartzscore','Sales','Year']

# %% [markdown]
# ## Regressão para Cópias Vendidas
# Iremos criar uma regressão linear somente com as variaveis quantitativas para estimar o número de cópias vendidas

# %%
# Separaremos as preditoras
quant_sales = quantitativas.copy()
quant_sales.remove('Sales')
np.asarray(dados);

# %%
results_quantitativas_sales = regress(((dados_sales.loc[:, quant_sales]).fillna(0)).astype(float), y_train)

# %%
results_quantitativas_sales.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.193
# Model:                            OLS   Adj. R-squared:                  0.192
# Method:                 Least Squares   F-statistic:                     168.3
# Date:                Thu, 21 Nov 2019   Prob (F-statistic):          6.21e-161
# Time:                        10:17:16   Log-Likelihood:                -8366.6
# No. Observations:                3529   AIC:                         1.675e+04
# Df Residuals:                    3523   BIC:                         1.678e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            51.0683     17.964      2.843      0.004      15.846      86.290
# Rank             -0.0002   9.17e-06    -20.728      0.000      -0.000      -0.000
# Critic_Score      0.2185      0.033      6.581      0.000       0.153       0.284
# User_Score        0.2138      0.027      7.968      0.000       0.161       0.266
# Vgchartzscore     0.0199      0.020      0.985      0.325      -0.020       0.059
# Year             -0.0251      0.009     -2.804      0.005      -0.043      -0.008
# ==============================================================================
# Omnibus:                     6442.384   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         13791272.896
# Skew:                          13.086   Prob(JB):                         0.00
# Kurtosis:                     308.134   Cond. No.                     3.52e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.52e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
quant_sales2 = quant_sales.copy()
quant_sales2.remove('Vgchartzscore')

# %%
results_quantitativas_sales_2 = regress(((dados_sales.loc[:, quant_sales2]).fillna(0)).astype(float), y_train)

# %%
results_quantitativas_sales_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.193
# Model:                            OLS   Adj. R-squared:                  0.192
# Method:                 Least Squares   F-statistic:                     210.2
# Date:                Thu, 21 Nov 2019   Prob (F-statistic):          6.52e-162
# Time:                        10:17:16   Log-Likelihood:                -8367.1
# No. Observations:                3529   AIC:                         1.674e+04
# Df Residuals:                    3524   BIC:                         1.678e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           48.9976     17.841      2.746      0.006      14.018      83.977
# Rank            -0.0002   9.14e-06    -20.853      0.000      -0.000      -0.000
# Critic_Score     0.2215      0.033      6.697      0.000       0.157       0.286
# User_Score       0.2215      0.026      8.629      0.000       0.171       0.272
# Year            -0.0240      0.009     -2.707      0.007      -0.041      -0.007
# ==============================================================================
# Omnibus:                     6441.592   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         13767571.334
# Skew:                          13.083   Prob(JB):                         0.00
# Kurtosis:                     307.870   Cond. No.                     3.50e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.5e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sales_teste1= sm.add_constant(teste[quant_sales2])
y_previsto_sales1 = results_quantitativas_sales_2.predict(sales_teste1)

# %%
e = 0.1
teste_sales = []
acertos_sales = []
for previsao,real in zip(y_previsto_sales1,y_test):
    if previsao <= real + real*e and previsao >= real - real*e:

        acertos_sales.append(1)

    teste_sales.append(0)
    
acertos_sales_1 = ((len(acertos_sales)/len(teste_sales))*100)
print("A taxa de acertos foi de {0:.2f}%".format(acertos_sales_1))
# Out:
# A taxa de acertos foi de 3.40%

# %%
metrics.r2_score(y_test,y_previsto_sales1)
# Out:
# 0.2472040984660946

# %% [markdown]
# ## Regressão para Nota dos Críticos
# Iremos criar uma regressão linear somente com as variaveis quantitativas para estimar a nota dos críticos

# %%
dados_score,teste, y_train_score, y_test = train_test_split(data,data.Critic_Score, test_size=0.25, random_state=RANDOM_SEED)
quant_score = quantitativas.copy()
quant_score.remove('Critic_Score')

# %%
results_quantitativas_score = regress(((dados_score.loc[:, quant_score]).fillna(0)).astype(float), y_train_score)
results_quantitativas_score.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Critic_Score   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.168
# Method:                 Least Squares   F-statistic:                     143.2
# Date:                Thu, 21 Nov 2019   Prob (F-statistic):          1.11e-138
# Time:                        10:17:17   Log-Likelihood:                -5950.2
# No. Observations:                3529   AIC:                         1.191e+04
# Df Residuals:                    3523   BIC:                         1.195e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            32.8216      9.052      3.626      0.000      15.074      50.569
# Rank          -8.671e-05   4.67e-06    -18.555      0.000   -9.59e-05   -7.76e-05
# User_Score        0.0429      0.014      3.147      0.002       0.016       0.070
# Vgchartzscore     0.0530      0.010      5.233      0.000       0.033       0.073
# Sales             0.0556      0.008      6.581      0.000       0.039       0.072
# Year             -0.0125      0.005     -2.775      0.006      -0.021      -0.004
# ==============================================================================
# Omnibus:                      376.130   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              525.613
# Skew:                          -0.834   Prob(JB):                    7.32e-115
# Kurtosis:                       3.891   Cond. No.                     3.52e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.52e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
score_teste1= sm.add_constant(teste[quant_score])
y_previsto_score1 = results_quantitativas_score.predict(score_teste1)

# %%
e = 0.1
teste_score = []
acertos_score = []
for previsao,real in zip(y_previsto_score1,y_test):
    if previsao <= real + real*e and previsao >= real - real*e:

        acertos_score.append(1)

    teste_score.append(0)
    
    
acertos_score_1 = ((len(acertos_score)/len(teste_score))*100)
print("A taxa de acertos foi de {0:.2f}%".format(acertos_score_1))
# Out:
# A taxa de acertos foi de 46.30%

# %%
metrics.r2_score(y_test,y_previsto_score1)
# Out:
# 0.15574710932358837

# %% [markdown]
# # Regressão com Dummy para quantidade de cópias vendidas

# %%
def dummify(data, column_name):
    """
        Converte a coluna column_name em dummies / one-hot e as adiciona ao dataframe
        retorna uma copia do  df original *sem* a coluna que foi dummified
    """
    df = data.copy()
    # Nota: se você for um econometrista, pode se interessar por usar a opção dropFirst = True na get_dummies
    df2 = pd.concat([df.drop(column_name, axis=1), pd.get_dummies(data[column_name], prefix=column_name)], axis=1)
    return df2

# %%
res = dummify(dados, ['Genre', 'ESRB_Rating', 'Platform',
       'Publisher', 'Developer'])
dados_sales,teste_sales, y_train, y_test_sales = train_test_split(res.drop('Sales', 1),res.Sales, test_size=0.25, random_state=RANDOM_SEED)

# %%
z = res.drop(columns=quantitativas)

# %%
quant_sales2.extend(z)
quant_sales2.remove("Rank")
quant_sales2.remove("Name")
quant_sales2.remove("basename")
quant_sales2.remove("Last_Update")

# %%
dummy_sales = regress(((dados_sales.loc[:,quant_sales2]).fillna(0)).astype(float), y_train)

# %%
dummy_sales.summary();
# Out:
# C:\Users\gabri\Anaconda3\lib\site-packages\statsmodels\base\model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# C:\Users\gabri\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\gabri\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\gabri\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
valorp = dummy_sales.pvalues
deixar = []
pcrit = 0.10
for indice,valor in valorp.items():
    if valor <= pcrit:
        deixar.append(indice)
del(deixar[0])

# %%
params_sales_1 = deixar

# %%
dummy_sales2 = regress(((dados_sales.loc[:,params_sales_1]).fillna(0)).astype(float), y_train)

# %%
dummy_sales2.summary();

# %%
valorp2 = dummy_sales2.pvalues
deixar2 = []
pcrit = 0.10
for indice,valor in valorp2.items():
    if valor <= pcrit:
        deixar2.append(indice)
del(deixar2[0])

# %%
params_sales_2 = deixar2

# %%
dummy_sales3 = regress(((dados_sales.loc[:,params_sales_2]).fillna(0)).astype(float), y_train)

# %%
dummy_sales3.summary();

# %%
valorp3 = dummy_sales3.pvalues
deixar3 = []
pcrit = 0.10
for indice,valor in valorp3.items():
    if valor <= pcrit:
        deixar3.append(indice)
del(deixar3[0])

# %%
params_sales_3 = deixar3

# %%
dummy_sales4 = regress(((dados_sales.loc[:,params_sales_3]).fillna(0)).astype(float), y_train)

# %%
dummy_sales4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.407
# Method:                 Least Squares   F-statistic:                     44.98
# Date:                Thu, 21 Nov 2019   Prob (F-statistic):               0.00
# Time:                        10:17:22   Log-Likelihood:                -7795.5
# No. Observations:                3529   AIC:                         1.570e+04
# Df Residuals:                    3473   BIC:                         1.605e+04
# Df Model:                          55
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# const                                        0.1556      0.066      2.374      0.018       0.027       0.284
# Genre_Fighting                               0.2691      0.166      1.620      0.105      -0.057       0.595
# Genre_MMO                                    1.5761      0.842      1.871      0.061      -0.075       3.227
# Genre_Platform                               0.3312      0.141      2.355      0.019       0.055       0.607
# Genre_Racing                                 0.2888      0.150      1.927      0.054      -0.005       0.583
# Genre_Sports                                 0.5055      0.119      4.246      0.000       0.272       0.739
# Platform_DS                                  0.4269      0.155      2.756      0.006       0.123       0.731
# Platform_GB                                  5.1296      0.767      6.692      0.000       3.627       6.633
# Platform_NES                                19.7116      1.729     11.401      0.000      16.322      23.101
# Platform_PS                                  0.5717      0.179      3.197      0.001       0.221       0.922
# Platform_PS2                                 0.9811      0.151      6.480      0.000       0.684       1.278
# Platform_PS3                                 0.8420      0.128      6.583      0.000       0.591       1.093
# Platform_PS4                                 1.6564      0.284      5.839      0.000       1.100       2.213
# Platform_SNES                                1.8277      0.637      2.867      0.004       0.578       3.078
# Platform_Wii                                 0.8349      0.149      5.588      0.000       0.542       1.128
# Platform_X360                                0.6631      0.120      5.515      0.000       0.427       0.899
# Platform_XOne                                1.0321      0.335      3.078      0.002       0.375       1.689
# Publisher_Arc System Works                2.255e-16   4.34e-15      0.052      0.959   -8.28e-15    8.73e-15
# Publisher_Broderbund                         2.9222      1.111      2.630      0.009       0.744       5.101
# Publisher_Edmund McMillen                    3.5072      1.111      3.157      0.002       1.329       5.686
# Publisher_Facepunch Studios                  4.4972      1.111      4.048      0.000       2.319       6.676
# Publisher_Nintendo                           0.9249      0.160      5.775      0.000       0.611       1.239
# Publisher_RedOctane                          2.9637      0.911      3.253      0.001       1.178       4.750
# Publisher_SCS Software                       2.9122      1.111      2.621      0.009       0.734       5.091
# Publisher_Sony Interactive Entertainment     2.3575      1.043      2.259      0.024       0.312       4.403
# Publisher_Square                             2.0709      0.729      2.840      0.005       0.641       3.501
# Publisher_Ultra Games                      -16.0284      2.815     -5.694      0.000     -21.548     -10.509
# Publisher_VU Games                           2.3501      0.921      2.551      0.011       0.544       4.156
# Developer_Bandai Namco Games                 1.6926      0.621      2.727      0.006       0.476       2.909
# Developer_Bungie                             9.1513      2.224      4.115      0.000       4.791      13.512
# Developer_Bungie Studios                     6.7261      1.112      6.048      0.000       4.546       8.907
# Developer_Core Design Ltd.                   3.6627      1.580      2.318      0.020       0.565       6.761
# Developer_Cyan Worlds                        2.9222      1.111      2.630      0.009       0.744       5.101
# Developer_EA DICE                            2.1577      0.998      2.162      0.031       0.201       4.115
# Developer_Edmund McMillen                    3.5072      1.111      3.157      0.002       1.329       5.686
# Developer_Facepunch Studios                  4.4972      1.111      4.048      0.000       2.319       6.676
# Developer_Game Freak                        10.3215      0.759     13.594      0.000       8.833      11.810
# Developer_Good Science Studio               23.1813      2.224     10.424      0.000      18.821      27.542
# Developer_Infinity Ward                      5.3036      0.577      9.198      0.000       4.173       6.434
# Developer_Mojang AB                         29.8544      2.222     13.435      0.000      25.497      34.211
# Developer_Naughty Dog                        4.2572      0.858      4.964      0.000       2.576       5.939
# Developer_Nintendo                           1.1346      0.576      1.968      0.049       0.004       2.265
# Developer_Nintendo EAD                       8.3192      0.350     23.795      0.000       7.634       9.005
# Developer_Nintendo EAD Tokyo                 5.4323      1.125      4.830      0.000       3.227       7.637
# Developer_Nintendo EPD                       3.1096      0.614      5.065      0.000       1.906       4.313
# Developer_Nintendo SDD                      15.4376      1.583      9.755      0.000      12.335      18.540
# Developer_Office Create                      2.4722      1.114      2.219      0.027       0.288       4.657
# Developer_Polyphony Digital                  8.6823      1.006      8.635      0.000       6.711      10.654
# Developer_Project Sora                       5.6775      1.581      3.592      0.000       2.578       8.777
# Developer_Reflections Interactive            4.7727      1.580      3.021      0.003       1.675       7.871
# Developer_Rockstar Games                    12.1280      2.239      5.418      0.000       7.739      16.517
# Developer_Rockstar North                     6.4417      0.620     10.395      0.000       5.227       7.657
# Developer_Rocksteady Studios                 2.7960      0.909      3.076      0.002       1.014       4.578
# Developer_SCS Software                       2.9122      1.111      2.621      0.009       0.734       5.091
# Developer_SIE Japan Studio                  -3.5670      1.634     -2.183      0.029      -6.771      -0.363
# Developer_Sledgehammer Games                 8.6530      1.595      5.424      0.000       5.525      11.781
# Developer_Square                            -8.7947      1.376     -6.389      0.000     -11.493      -6.096
# Developer_Traveller's Tales                  0.6985      0.339      2.063      0.039       0.035       1.362
# Developer_Treyarch                           1.8275      0.526      3.473      0.001       0.796       2.859
# Developer_Ubisoft Paris                      0.9759      0.560      1.742      0.082      -0.123       2.074
# Developer_Valve Software                     3.6226      0.750      4.832      0.000       2.153       5.092
# ==============================================================================
# Omnibus:                     6174.549   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17268088.757
# Skew:                          11.742   Prob(JB):                         0.00
# Kurtosis:                     344.885   Cond. No.                     1.33e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.18e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# # Teste da Regressão

# %% [markdown]
# **Cópias Vendidas**

# %%
sales_teste= sm.add_constant(teste_sales[params_sales_3])
y_previsto_sales = dummy_sales4.predict(sales_teste)

# %%
e = 0.1
teste_sales = []
acertos_sales = []
for previsao,real in zip(y_previsto_sales,y_test_sales):
    if previsao <= real + real*e and previsao >= real - real*e:

        acertos_sales.append(1)

    teste_sales.append(0)
     
acertos_sales_ = ((len(acertos_sales)/len(teste_sales))*100)
print("A taxa de acertos foi de {0:.2f}%".format(acertos_sales_))
# Out:
# A taxa de acertos foi de 5.01%

# %%
metrics.r2_score(y_test_sales,y_previsto_sales)
# Out:
# 0.30688637976884603

# %% [markdown]
# # Regressão com Dummy para Nota do jogo

# %%
dados_score,teste_score, y_train_, y_test_score = train_test_split(res,res.Critic_Score, test_size=0.25, random_state=RANDOM_SEED)
dummy_score = quant_score.copy()
dummy_score.extend(z)
dummy_score.remove("Rank")
dummy_score.remove("Name")
dummy_score.remove("basename")
dummy_score.remove("Last_Update")

# %%
results_dummy_score = regress(((dados_score.loc[:,dummy_score]).fillna(0)).astype(float), y_train_)
results_dummy_score.summary();
# Out:
# C:\Users\gabri\Anaconda3\lib\site-packages\statsmodels\base\model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# C:\Users\gabri\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\gabri\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\gabri\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
valorp_2 = results_dummy_score.pvalues
deixar_2 = []
pcrit = 0.10
for indice,valor in valorp_2.items():
    if valor <= pcrit:
        deixar_2.append(indice)
del(deixar_2[0])

# %%
dummy_score2 = deixar_2

# %%
dummy_score_2 = regress(((dados_score.loc[:,dummy_score2]).fillna(0)).astype(float), y_train_)
dummy_score_2.summary();

# %%
valorp_3 = dummy_score_2.pvalues
deixar_3 = []
pcrit = 0.10
for indice,valor in valorp_3.items():
    if valor <= pcrit:
        deixar_3.append(indice)
del(deixar_3[0])

dummy_score3 = deixar_3

# %%
dummy_score_3 = regress(((dados_score.loc[:,dummy_score3]).fillna(0)).astype(float), y_train_)
dummy_score_3.summary();

# %%
valorp_4 = dummy_score_3.pvalues
deixar_4 = []
pcrit = 0.10
for indice,valor in valorp_4.items():
    if valor <= pcrit:
        deixar_4.append(indice)
del(deixar_4[0])

dummy_score4 = deixar_4

# %%
dummy_score_4 = regress(((dados_score.loc[:,dummy_score4]).fillna(0)).astype(float), y_train_)
dummy_score_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Critic_Score   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.476
# Method:                 Least Squares   F-statistic:                     11.53
# Date:                Thu, 21 Nov 2019   Prob (F-statistic):               0.00
# Time:                        10:17:28   Log-Likelihood:                -4978.2
# No. Observations:                3529   AIC:                         1.057e+04
# Df Residuals:                    3224   BIC:                         1.245e+04
# Df Model:                         304
# Covariance Type:            nonrobust
# ===========================================================================================================================================
#                                                                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                      66.1810      9.655      6.855      0.000      47.250      85.112
# User_Score                                                                  0.0224      0.011      1.962      0.050    1.59e-05       0.045
# Vgchartzscore                                                               0.0646      0.008      7.606      0.000       0.048       0.081
# Sales                                                                       0.0727      0.007     10.677      0.000       0.059       0.086
# Year                                                                       -0.0361      0.006     -6.441      0.000      -0.047      -0.025
# Genre_Action                                                                1.5220      0.316      4.817      0.000       0.902       2.142
# Genre_Action-Adventure                                                      2.1065      0.338      6.240      0.000       1.445       2.768
# Genre_Adventure                                                             1.8977      0.321      5.910      0.000       1.268       2.527
# Genre_Education                                                             2.3836      1.084      2.198      0.028       0.258       4.510
# Genre_Fighting                                                              2.0117      0.323      6.225      0.000       1.378       2.645
# Genre_MMO                                                                   1.9938      0.505      3.949      0.000       1.004       2.984
# Genre_Misc                                                                  1.8147      0.318      5.706      0.000       1.191       2.438
# Genre_Music                                                                 2.4608      0.418      5.893      0.000       1.642       3.279
# Genre_Platform                                                              1.9546      0.316      6.180      0.000       1.334       2.575
# Genre_Puzzle                                                                2.1533      0.329      6.549      0.000       1.509       2.798
# Genre_Racing                                                                1.8381      0.319      5.762      0.000       1.213       2.464
# Genre_Role-Playing                                                          2.1895      0.316      6.932      0.000       1.570       2.809
# Genre_Sandbox                                                            3.781e-13   5.81e-14      6.504      0.000    2.64e-13    4.92e-13
# Genre_Shooter                                                               1.9866      0.318      6.238      0.000       1.362       2.611
# Genre_Simulation                                                            1.6583      0.326      5.093      0.000       1.020       2.297
# Genre_Sports                                                                1.9479      0.320      6.096      0.000       1.321       2.574
# Genre_Strategy                                                              2.1108      0.325      6.486      0.000       1.473       2.749
# Genre_Visual Novel                                                          3.4305      1.121      3.061      0.002       1.233       5.628
# ESRB_Rating_0                                                              10.8206      1.608      6.728      0.000       7.667      13.974
# ESRB_Rating_E                                                              10.8681      1.605      6.773      0.000       7.722      14.014
# ESRB_Rating_E10                                                            10.8563      1.618      6.708      0.000       7.683      14.029
# ESRB_Rating_M                                                              11.3010      1.613      7.008      0.000       8.139      14.463
# ESRB_Rating_RP                                                             11.2449      1.704      6.601      0.000       7.905      14.585
# ESRB_Rating_T                                                              11.0900      1.610      6.889      0.000       7.934      14.247
# Platform_DC                                                                 1.3406      0.235      5.704      0.000       0.880       1.801
# Platform_GBC                                                                1.7444      0.609      2.866      0.004       0.551       2.938
# Platform_N64                                                                0.7080      0.141      5.025      0.000       0.432       0.984
# Platform_NS                                                                 0.8022      0.140      5.725      0.000       0.527       1.077
# Platform_PC                                                                 0.8698      0.076     11.519      0.000       0.722       1.018
# Platform_PS2                                                                0.3262      0.075      4.346      0.000       0.179       0.473
# Platform_PS3                                                                0.3922      0.069      5.700      0.000       0.257       0.527
# Platform_PS4                                                                0.5864      0.145      4.050      0.000       0.303       0.870
# Platform_SAT                                                                1.0630      0.383      2.772      0.006       0.311       1.815
# Platform_SNES                                                               0.9741      0.295      3.307      0.001       0.397       1.552
# Platform_WiiU                                                               0.7381      0.165      4.478      0.000       0.415       1.061
# Platform_X360                                                               0.2905      0.065      4.487      0.000       0.164       0.417
# Platform_XB                                                                 0.6485      0.127      5.107      0.000       0.400       0.897
# Platform_XOne                                                               0.7060      0.177      3.987      0.000       0.359       1.053
# Publisher_4-Aug                                                             0.9121      0.524      1.742      0.082      -0.114       1.939
# Publisher_989 Studios                                                      -2.1478      0.638     -3.365      0.001      -3.399      -0.896
# Publisher_Acclaim Entertainment                                             0.8265      0.254      3.254      0.001       0.329       1.324
# Publisher_Accolade                                                         -5.2066      1.604     -3.247      0.001      -8.351      -2.062
# Publisher_Agetec                                                           -0.8968      0.332     -2.701      0.007      -1.548      -0.246
# Publisher_Aksys Games                                                       0.7234      0.281      2.577      0.010       0.173       1.274
# Publisher_Atlus                                                             0.4844      0.135      3.589      0.000       0.220       0.749
# Publisher_Capcom                                                            0.7488      0.104      7.215      0.000       0.545       0.952
# Publisher_Crave Entertainment                                              -1.9043      0.272     -7.002      0.000      -2.438      -1.371
# Publisher_D3Publisher                                                      -6.2548      1.483     -4.217      0.000      -9.163      -3.347
# Publisher_DSI Games                                                        -1.2403      0.521     -2.382      0.017      -2.261      -0.219
# Publisher_Destination Software, Inc                                         1.9620      0.776      2.528      0.012       0.440       3.484
# Publisher_Disney Interactive Studios                                        0.6332      0.197      3.207      0.001       0.246       1.020
# Publisher_EA Sports                                                         0.6998      0.166      4.224      0.000       0.375       1.025
# Publisher_EA Sports BIG                                                     1.1962      0.374      3.195      0.001       0.462       1.930
# Publisher_Electronic Arts                                                   0.1898      0.081      2.357      0.018       0.032       0.348
# Publisher_Excalibur Publishing                                             -2.7142      0.524     -5.175      0.000      -3.743      -1.686
# Publisher_GT Interactive                                                   -1.5146      0.498     -3.039      0.002      -2.492      -0.538
# Publisher_Global Star Software                                             -2.5879      0.737     -3.510      0.000      -4.034      -1.142
# Publisher_Graffiti                                                          2.8489      1.079      2.641      0.008       0.734       4.964
# Publisher_Inti Creates                                                      2.1852      1.047      2.088      0.037       0.133       4.237
# Publisher_Kemco                                                            -2.4060      0.523     -4.602      0.000      -3.431      -1.381
# Publisher_Koei Tecmo                                                        1.5138      0.569      2.659      0.008       0.398       2.630
# Publisher_LucasArts                                                         0.5068      0.176      2.887      0.004       0.163       0.851
# Publisher_Mastiff                                                          -4.0091      1.040     -3.853      0.000      -6.049      -1.969
# Publisher_Matt Makes Games Inc.                                             0.9166      0.522      1.758      0.079      -0.106       1.939
# Publisher_Merge Games                                                       1.0495      0.524      2.002      0.045       0.022       2.077
# Publisher_Meridian4                                                        -1.9311      0.522     -3.699      0.000      -2.955      -0.907
# Publisher_Metro 3D                                                         -1.4761      0.521     -2.835      0.005      -2.497      -0.455
# Publisher_Microsoft Game Studios                                            0.3876      0.168      2.304      0.021       0.058       0.717
# Publisher_Natsume                                                           0.5767      0.220      2.623      0.009       0.146       1.008
# Publisher_NewKidCo                                                         -1.4154      0.520     -2.721      0.007      -2.435      -0.395
# Publisher_Nintendo                                                          0.7350      0.079      9.253      0.000       0.579       0.891
# Publisher_Phantom EFX                                                      -1.3183      0.520     -2.533      0.011      -2.339      -0.298
# Publisher_Playlogic Game Factory                                            3.2875      1.468      2.240      0.025       0.410       6.165
# Publisher_Sam Barlow                                                        0.8273      0.524      1.578      0.115      -0.201       1.855
# Publisher_Sony Computer Entertainment                                       0.5351      0.098      5.438      0.000       0.342       0.728
# Publisher_Square Enix                                                       0.2781      0.127      2.194      0.028       0.030       0.527
# Publisher_Studio Wildcard                                                  -1.6655      0.527     -3.161      0.002      -2.699      -0.632
# Publisher_Titus                                                            -2.5528      0.604     -4.229      0.000      -3.736      -1.369
# Publisher_Tommo                                                            -1.4008      0.491     -2.854      0.004      -2.363      -0.438
# Publisher_Trendy Entertainment                                           5.974e-16      2e-15      0.298      0.766   -3.33e-15    4.53e-15
# Publisher_UFO Interactive                                                  -2.5256      0.520     -4.855      0.000      -3.546      -1.506
# Publisher_Unknown                                                           0.5382      0.289      1.860      0.063      -0.029       1.106
# Publisher_Villa Gorilla                                                     1.3241      0.373      3.552      0.000       0.593       2.055
# Publisher_Warner Bros. Interactive                                          0.5326      0.181      2.935      0.003       0.177       0.888
# Publisher_Whiptail Interactive                                             -1.6820      0.521     -3.230      0.001      -2.703      -0.661
# Publisher_Xicat Interactive                                                 1.9258      1.123      1.714      0.087      -0.277       4.128
# Publisher_Yacht Club Games                                                  1.0130      0.373      2.714      0.007       0.281       1.745
# Developer_10tacle Studios AG                                               -3.6008      1.042     -3.455      0.001      -5.644      -1.558
# Developer_2K Australia / 2K Boston                                          1.4520      0.739      1.965      0.049       0.003       2.901
# Developer_2XL Games                                                        -1.7498      0.740     -2.366      0.018      -3.200      -0.300
# Developer_8MonkeyLabs                                                      -1.3183      0.520     -2.533      0.011      -2.339      -0.298
# Developer_A2M                                                              -0.9927      0.467     -2.123      0.034      -1.909      -0.076
# Developer_AMA Studios                                                      -3.8510      1.042     -3.695      0.000      -5.894      -1.808
# Developer_Acclaim Studios Austin                                           -2.4994      0.581     -4.304      0.000      -3.638      -1.361
# Developer_Acclaim Studios Cheltenham                                       -2.1363      0.779     -2.741      0.006      -3.664      -0.608
# Developer_Activision Value                                                 -3.1190      0.605     -5.157      0.000      -4.305      -1.933
# Developer_Airtight Games                                                   -1.4099      0.610     -2.310      0.021      -2.607      -0.213
# Developer_Ambrella                                                         -1.0143      0.605     -1.675      0.094      -2.201       0.173
# Developer_Appaloosa Interactive                                            -1.2362      0.608     -2.032      0.042      -2.429      -0.043
# Developer_Argonaut Games                                                   -0.6279      0.351     -1.791      0.073      -1.315       0.059
# Developer_Arkane Studios / Floodgate Entertainment / Kuju Entertainment    -2.4829      1.042     -2.384      0.017      -4.525      -0.441
# Developer_Artificial Mind & Movement                                        3.2305      1.274      2.536      0.011       0.733       5.728
# Developer_Artificial Mind and Movement                                     -0.9552      0.283     -3.378      0.001      -1.510      -0.401
# Developer_Artoon                                                           -1.9397      0.468     -4.140      0.000      -2.858      -1.021
# Developer_Asobo Studio                                                     -1.1078      0.469     -2.363      0.018      -2.027      -0.189
# Developer_Atari                                                            -1.5118      0.743     -2.035      0.042      -2.968      -0.055
# Developer_Bandai Namco Games / NOW Production                           -5.673e-16   1.41e-15     -0.403      0.687   -3.33e-15    2.19e-15
# Developer_Behaviour Interactive Inc.                                       -1.4187      0.736     -1.928      0.054      -2.861       0.024
# Developer_Bethesda Softworks                                                0.7033      0.375      1.875      0.061      -0.032       1.439
# Developer_Big Red Button                                                   -3.4942      1.057     -3.307      0.001      -5.566      -1.423
# Developer_Big Red Software                                                 -3.5611      1.044     -3.411      0.001      -5.608      -1.514
# Developer_Bizarre Creations                                                 1.0182      0.339      3.006      0.003       0.354       1.683
# Developer_Blade Interactive                                                -2.6664      1.041     -2.561      0.010      -4.708      -0.625
# Developer_Blitz Games                                                      -1.0176      0.353     -2.883      0.004      -1.710      -0.326
# Developer_Blue Omega Entertainment                                         -3.9361      0.737     -5.338      0.000      -5.382      -2.490
# Developer_Bluepoint Games                                                   1.1972      0.530      2.258      0.024       0.158       2.236
# Developer_BudCat Creations                                                  1.1119      0.603      1.843      0.065      -0.071       2.295
# Developer_Buzz Monkey Software                                             -2.3158      1.043     -2.221      0.026      -4.361      -0.271
# Developer_Capybara Games                                                    1.8899      1.041      1.816      0.069      -0.151       3.931
# Developer_Cave Barn                                                        -2.2899      1.040     -2.201      0.028      -4.329      -0.250
# Developer_Cavia Inc.                                                       -1.0976      0.428     -2.562      0.010      -1.938      -0.258
# Developer_City Interactive                                                 -2.7456      0.603     -4.553      0.000      -3.928      -1.563
# Developer_Clap Hanz                                                         0.9703      0.609      1.593      0.111      -0.224       2.164
# Developer_Codemasters Birmingham                                            1.2690      0.379      3.351      0.001       0.526       2.011
# Developer_ColdWood Interactive                                             -2.9870      1.046     -2.855      0.004      -5.038      -0.936
# Developer_Collision Studios                                                -1.8913      0.605     -3.129      0.002      -3.077      -0.706
# Developer_Compile Heart                                                    -1.1850      0.497     -2.384      0.017      -2.160      -0.210
# Developer_ConcernedApe                                                      2.2148      1.057      2.095      0.036       0.142       4.288
# Developer_Cooking Mama Limited                                             -2.3771      1.043     -2.278      0.023      -4.423      -0.331
# Developer_Crawfish Interactive                                             -1.5279      0.743     -2.058      0.040      -2.984      -0.072
# Developer_Criterion                                                         1.8846      0.744      2.534      0.011       0.426       3.343
# Developer_Criterion Games                                                   1.5986      0.358      4.460      0.000       0.896       2.301
# Developer_Crystal Dynamics                                                  0.7741      0.294      2.629      0.009       0.197       1.351
# Developer_Crytek                                                            0.8273      0.435      1.903      0.057      -0.025       1.680
# Developer_DECK13 Interactive                                               -1.9957      0.738     -2.706      0.007      -3.442      -0.550
# Developer_DMA Design                                                        1.0062      0.524      1.920      0.055      -0.022       2.034
# Developer_Danger Productions                                               -4.8095      1.049     -4.583      0.000      -6.867      -2.752
# Developer_Data Design Interactive                                          -2.5256      0.520     -4.855      0.000      -3.546      -1.506
# Developer_Day 1 Studios                                                    -1.8494      0.748     -2.471      0.014      -3.317      -0.382
# Developer_Destination Software                                             -5.0892      1.296     -3.925      0.000      -7.631      -2.547
# Developer_Digital Eclipse                                                   0.6288      0.333      1.888      0.059      -0.024       1.282
# Developer_Digital Illusions (DICE)                                         -3.6274      1.042     -3.482      0.001      -5.670      -1.585
# Developer_Double Fine Productions                                           0.7205      0.431      1.672      0.095      -0.124       1.565
# Developer_Double Helix Games                                               -1.5967      0.432     -3.697      0.000      -2.444      -0.750
# Developer_DreamWorks Interactive                                            1.8273      1.043      1.751      0.080      -0.218       3.873
# Developer_EA Canada                                                         0.3544      0.182      1.945      0.052      -0.003       0.712
# Developer_EA Digital Illusions CE                                           0.5903      0.404      1.462      0.144      -0.202       1.382
# Developer_EA Tiburon                                                        0.3938      0.197      1.997      0.046       0.007       0.781
# Developer_EC Interactive Games                                             -1.2403      0.521     -2.382      0.017      -2.261      -0.219
# Developer_Eidetic                                                           4.0496      1.219      3.321      0.001       1.659       6.440
# Developer_Eidos Montreal                                                    1.0234      0.616      1.662      0.097      -0.184       2.231
# Developer_Epic Games                                                        0.6458      0.401      1.610      0.108      -0.141       1.432
# Developer_Epicenter Interactive                                            -2.8455      1.299     -2.191      0.029      -5.392      -0.299
# Developer_Eutechnyx                                                        -1.5030      0.471     -3.191      0.001      -2.427      -0.580
# Developer_FarSight Studios                                                  3.0735      0.783      3.925      0.000       1.538       4.609
# Developer_FeelPlus                                                         -2.8572      1.043     -2.741      0.006      -4.901      -0.813
# Developer_Firaxis Games                                                     1.5000      0.379      3.959      0.000       0.757       2.243
# Developer_FireFly Studios                                                  -3.5115      0.742     -4.736      0.000      -4.965      -2.058
# Developer_Flagship Co., Ltd. / Nintendo EAD                                 1.9904      1.043      1.909      0.056      -0.054       4.035
# Developer_Fluid Studios                                                    -1.4154      0.520     -2.721      0.007      -2.435      -0.395
# Developer_FreeStyle Games                                                   1.7319      0.606      2.859      0.004       0.544       2.920
# Developer_FreeStyleGames                                                    1.0568      0.531      1.992      0.047       0.016       2.097
# Developer_Full Fat                                                         -0.9204      0.476     -1.933      0.053      -1.854       0.013
# Developer_G Artist                                                         -2.5140      1.046     -2.404      0.016      -4.564      -0.464
# Developer_GREZZO                                                            1.6217      0.531      3.055      0.002       0.581       2.662
# Developer_GRIN                                                             -1.5711      0.610     -2.577      0.010      -2.766      -0.376
# Developer_Game Republic                                                    -1.1744      0.396     -2.965      0.003      -1.951      -0.398
# Developer_Genius Sonority Inc.                                             -2.0944      0.605     -3.460      0.001      -3.281      -0.908
# Developer_Ghost Town Games                                                  1.5195      0.759      2.002      0.045       0.031       3.008
# Developer_HB Studios Multimedia                                            -1.9801      0.605     -3.273      0.001      -3.166      -0.794
# Developer_Headup Games / Crenetic                                          -1.9311      0.522     -3.699      0.000      -2.955      -0.907
# Developer_Hellbent Games                                                   -2.1981      1.059     -2.075      0.038      -4.275      -0.121
# Developer_Hydravision Entertainment                                        -4.0577      1.043     -3.892      0.000      -6.102      -2.013
# Developer_Hypnos Entertainment, Inc.                                        1.5730      0.741      2.124      0.034       0.121       3.025
# Developer_IO Interactive                                                    0.8061      0.332      2.425      0.015       0.154       1.458
# Developer_Iguana Entertainment                                             -1.3630      0.540     -2.524      0.012      -2.422      -0.304
# Developer_Imagineer Co., Ltd.                                              -2.1057      1.061     -1.984      0.047      -4.187      -0.025
# Developer_Infogrames                                                       -2.3452      1.048     -2.237      0.025      -4.400      -0.290
# Developer_Intelligent Systems                                               0.7616      0.235      3.242      0.001       0.301       1.222
# Developer_Jellyvision, Inc.                                                 0.8999      0.473      1.904      0.057      -0.027       1.827
# Developer_Judo Baby                                                         2.0029      0.776      2.582      0.010       0.482       3.524
# Developer_Jupiter Corporation                                              -1.2361      0.607     -2.038      0.042      -2.425      -0.047
# Developer_K2 LLC                                                           -1.7929      0.738     -2.428      0.015      -3.240      -0.345
# Developer_KCET                                                              1.7200      0.738      2.332      0.020       0.274       3.166
# Developer_Kalisto                                                          -2.9706      1.041     -2.854      0.004      -5.011      -0.930
# Developer_King of the Jungle                                               -2.0747      1.041     -1.993      0.046      -4.116      -0.033
# Developer_Klei Entertainment                                                2.4313      1.047      2.323      0.020       0.379       4.483
# Developer_Koei                                                             -1.0611      0.602     -1.761      0.078      -2.242       0.120
# Developer_Kojima Productions                                                1.0857      0.283      3.838      0.000       0.531       1.640
# Developer_Konami / Eighting                                                -2.3688      1.045     -2.267      0.023      -4.418      -0.320
# Developer_Konami Computer Entertainment Hawaii                             -1.1326      0.602     -1.883      0.060      -2.312       0.047
# Developer_Konami Computer Entertainment Japan                               1.1360      0.471      2.411      0.016       0.212       2.060
# Developer_Konami Computer Entertainment Tokyo                               0.8593      0.317      2.707      0.007       0.237       1.482
# Developer_Kronos Digital Entertainment                                    7.73e-15   1.07e-15      7.216      0.000    5.63e-15    9.83e-15
# Developer_Kung Fu Factory                                                  -2.2407      0.741     -3.023      0.003      -3.694      -0.787
# Developer_Kylotonn Entertainment                                           -3.2911      1.049     -3.137      0.002      -5.348      -1.234
# Developer_LTI                                                              -2.4176      1.042     -2.319      0.020      -4.461      -0.374
# Developer_Light Weight                                                     -2.0586      0.752     -2.736      0.006      -3.534      -0.584
# Developer_Liquid Entertainment                                             -2.8781      0.602     -4.784      0.000      -4.058      -1.699
# Developer_Livesay Technologies, Inc.                                       -3.0307      1.043     -2.907      0.004      -5.075      -0.987
# Developer_MachineGames                                                      1.0338      0.608      1.699      0.089      -0.159       2.227
# Developer_Magic Pockets                                                    -2.1416      0.737     -2.906      0.004      -3.586      -0.697
# Developer_Marvelous Entertainment                                           1.4221      0.606      2.345      0.019       0.233       2.611
# Developer_Matt Thorson                                                      0.9166      0.522      1.758      0.079      -0.106       1.939
# Developer_Mercury Steam                                                     1.0362      0.471      2.202      0.028       0.114       1.959
# Developer_Metro                                                             1.4190      0.640      2.217      0.027       0.164       2.674
# Developer_Metro3D                                                          -1.4761      0.521     -2.835      0.005      -2.497      -0.455
# Developer_Midas Interactive Entertainment                                  -3.0176      1.043     -2.892      0.004      -5.063      -0.972
# Developer_Midway                                                            1.1962      0.737      1.624      0.105      -0.248       2.641
# Developer_Minds-Eye Productions                                            -0.9784      0.740     -1.323      0.186      -2.429       0.472
# Developer_Mojang                                                            1.6768      1.055      1.590      0.112      -0.391       3.744
# Developer_Monumental Games                                                 -1.1373      0.537     -2.117      0.034      -2.191      -0.084
# Developer_Motion Twin                                                       1.0495      0.524      2.002      0.045       0.022       2.077
# Developer_NCS                                                              -5.9043      1.077     -5.482      0.000      -8.016      -3.793
# Developer_Namco                                                             0.9984      0.190      5.248      0.000       0.625       1.371
# Developer_NanaOn-Sha                                                        1.7582      1.046      1.680      0.093      -0.293       3.810
# Developer_Naughty Dog                                                       1.1872      0.404      2.938      0.003       0.395       1.980
# Developer_Neko Entertainment                                               -3.9543      0.736     -5.371      0.000      -5.398      -2.511
# Developer_NetherRealm Studios                                               1.0322      0.537      1.924      0.054      -0.020       2.084
# Developer_Neversoft Entertainment                                           0.8909      0.226      3.941      0.000       0.448       1.334
# Developer_Newcom                                                           -2.4350      1.053     -2.313      0.021      -4.499      -0.371
# Developer_Ninja Theory                                                      1.2197      0.604      2.020      0.043       0.036       2.404
# Developer_Nordic Games                                                     -2.7260      1.047     -2.603      0.009      -4.779      -0.673
# Developer_Oddworld Inhabitans                                               2.9497      1.153      2.558      0.011       0.689       5.210
# Developer_Oddworld Inhabitants                                              2.5954      1.153      2.251      0.024       0.335       4.856
# Developer_Omega Force                                                      -0.7707      0.221     -3.485      0.000      -1.204      -0.337
# Developer_One Man Band                                                     -2.5182      1.042     -2.418      0.016      -4.560      -0.476
# Developer_Other Ocean Interactive                                          -1.2666      0.603     -2.101      0.036      -2.448      -0.085
# Developer_OutLook Entertainment                                            -3.2594      1.041     -3.130      0.002      -5.301      -1.218
# Developer_Overkill Software                                                -2.4249      1.048     -2.315      0.021      -4.479      -0.371
# Developer_PagodaWest Games                                                  1.7785      1.048      1.698      0.090      -0.276       3.833
# Developer_Paradox Development                                              -1.6958      0.744     -2.280      0.023      -3.154      -0.237
# Developer_Piranha Bytes                                                    -1.9297      0.430     -4.483      0.000      -2.774      -1.086
# Developer_Pivotal Games                                                    -1.2055      0.523     -2.305      0.021      -2.231      -0.180
# Developer_PlatinumGames                                                     1.2137      0.429      2.826      0.005       0.372       2.056
# Developer_Playground Games                                                  2.1678      0.757      2.865      0.004       0.684       3.651
# Developer_Playlogic Game Factory                                           -5.3664      1.799     -2.982      0.003      -8.894      -1.838
# Developer_Probe                                                            -2.0949      1.070     -1.958      0.050      -4.193       0.003
# Developer_Project Soul                                                      1.2602      0.526      2.396      0.017       0.229       2.291
# Developer_Pronto Games                                                     -2.1804      1.040     -2.096      0.036      -4.220      -0.140
# Developer_Psyonix Studios                                                   1.7572      0.530      3.316      0.001       0.718       2.796
# Developer_Q Entertainment                                                   0.8883      0.526      1.688      0.091      -0.143       1.920
# Developer_Rayark Inc.                                                    1.876e-15      9e-16      2.084      0.037    1.11e-16    3.64e-15
# Developer_Rebellion Developments                                           -1.5819      0.295     -5.358      0.000      -2.161      -1.003
# Developer_Red Storm Entertainment                                          -2.5068      0.604     -4.153      0.000      -3.690      -1.323
# Developer_Reflections Interactive                                           1.5014      0.779      1.928      0.054      -0.025       3.028
# Developer_Relic                                                             1.0024      0.530      1.889      0.059      -0.038       2.043
# Developer_Retro Studios                                                     1.0644      0.528      2.015      0.044       0.029       2.100
# Developer_Revolution Software                                               1.2859      0.752      1.711      0.087      -0.188       2.759
# Developer_Robomodo / Buzz Monkey Software                                  -2.3912      0.741     -3.228      0.001      -3.843      -0.939
# Developer_Rockstar Leeds                                                    1.4127      0.428      3.304      0.001       0.574       2.251
# Developer_Rockstar Leeds/North                                              1.7371      1.048      1.658      0.097      -0.317       3.791
# Developer_Rockstar North                                                    1.4876      0.299      4.974      0.000       0.901       2.074
# Developer_Rockstar San Diego                                                1.5975      0.371      4.307      0.000       0.870       2.325
# Developer_Rockstar Toronto                                                  1.0117      0.602      1.679      0.093      -0.169       2.193
# Developer_Rocksteady Studios                                                1.8432      0.434      4.245      0.000       0.992       2.694
# Developer_Running With Scissors                                            -1.6820      0.521     -3.230      0.001      -2.703      -0.661
# Developer_SCE San Diego Studio                                              0.7049      0.346      2.039      0.042       0.027       1.383
# Developer_SCEA Santa Monica Studio                                          1.1624      0.613      1.896      0.058      -0.040       2.364
# Developer_SCi                                                              -3.6912      1.205     -3.064      0.002      -6.054      -1.329
# Developer_Saffire Corporation                                              -1.2686      0.467     -2.716      0.007      -2.185      -0.353
# Developer_Sam Barlow                                                        0.8273      0.524      1.578      0.115      -0.201       1.855
# Developer_Sandblast Games                                                  -2.1512      0.751     -2.863      0.004      -3.624      -0.678
# Developer_Savage Entertainment                                             -1.4917      0.528     -2.827      0.005      -2.526      -0.457
# Developer_Secret Level                                                     -2.3114      0.738     -3.134      0.002      -3.758      -0.865
# Developer_Seven45 Studios                                                  -3.9589      0.793     -4.990      0.000      -5.514      -2.403
# Developer_Shiny Entertainment                                              -1.8089      0.469     -3.856      0.000      -2.729      -0.889
# Developer_Silicon Knights                                                  -1.2430      0.468     -2.655      0.008      -2.161      -0.325
# Developer_Slightly Mad Studios                                              0.9823      0.530      1.852      0.064      -0.058       2.022
# Developer_Smart Dog                                                        -2.4399      1.048     -2.328      0.020      -4.495      -0.385
# Developer_Sony Computer Entertainment                                      -2.9448      0.744     -3.958      0.000      -4.403      -1.486
# Developer_Spark Unlimited                                                  -3.5653      0.737     -4.836      0.000      -5.011      -2.120
# Developer_Sports Interactive                                                0.8375      0.435      1.927      0.054      -0.015       1.690
# Developer_Stormfront Studios                                               -1.3774      0.741     -1.859      0.063      -2.830       0.075
# Developer_Studio Archcraft                                                 -3.9621      1.499     -2.642      0.008      -6.902      -1.022
# Developer_Studio Liverpool                                                  0.9070      0.610      1.486      0.137      -0.290       2.104
# Developer_Studio Wildcard                                                  -1.6655      0.527     -3.161      0.002      -2.699      -0.632
# Developer_Success                                                           3.9274      1.473      2.665      0.008       1.038       6.816
# Developer_Sunflower Studios                                                 1.7768      1.043      1.703      0.089      -0.269       3.822
# Developer_Sunflowers Interactive                                            1.4653      0.742      1.975      0.048       0.010       2.920
# Developer_Super Empire                                                     -2.0288      1.041     -1.950      0.051      -4.069       0.011
# Developer_THQ                                                              -0.9134      0.370     -2.466      0.014      -1.640      -0.187
# Developer_THQ Nordic                                                     3.638e-17   6.22e-16      0.058      0.953   -1.18e-15    1.26e-15
# Developer_TML Studios                                                      -2.7142      0.524     -5.175      0.000      -3.743      -1.686
# Developer_Takara                                                           -3.7732      1.040     -3.627      0.000      -5.813      -1.734
# Developer_Tantalus Interactive                                             -1.1268      0.620     -1.818      0.069      -2.342       0.089
# Developer_Team Bondi                                                        1.2849      0.609      2.109      0.035       0.091       2.479
# Developer_Team Land Ho!                                                    -2.2634      1.066     -2.124      0.034      -4.353      -0.174
# Developer_Tecmo Koei Games                                                 -1.7371      0.604     -2.878      0.004      -2.920      -0.554
# Developer_The Neverhood                                                    -2.6219      1.042     -2.516      0.012      -4.665      -0.579
# Developer_Toby Fox                                                          0.9121      0.524      1.742      0.082      -0.114       1.939
# Developer_Tommo                                                            -3.4037      0.775     -4.390      0.000      -4.924      -1.883
# Developer_Totally Games                                                    -1.9580      0.737     -2.658      0.008      -3.402      -0.514
# Developer_Treyarch                                                          0.4416      0.250      1.769      0.077      -0.048       0.931
# Developer_Turn 10 Studios                                                   1.7800      0.749      2.375      0.018       0.311       3.249
# Developer_Ubisoft Barcelona                                                -4.1231      1.053     -3.915      0.000      -6.188      -2.058
# Developer_Ubisoft Milan                                                    -2.8937      1.043     -2.776      0.006      -4.938      -0.850
# Developer_Ubisoft Montpellier                                               0.4788      0.304      1.575      0.115      -0.117       1.075
# Developer_Ubisoft Montreal                                                  0.2843      0.133      2.135      0.033       0.023       0.545
# Developer_Ubisoft Quebec                                                    1.7216      0.747      2.306      0.021       0.257       3.186
# Developer_Ubisoft Reflections                                               0.9682      0.527      1.837      0.066      -0.065       2.002
# Developer_Ubisoft San Francisco                                             1.2769      0.789      1.619      0.106      -0.270       2.823
# Developer_Ubisoft Shanghai                                                  0.8418      0.333      2.526      0.012       0.188       1.495
# Developer_Ubisoft Toronto                                                   0.8445      0.539      1.567      0.117      -0.212       1.901
# Developer_Ubisoft Vancouver                                                -1.8292      0.605     -3.023      0.003      -3.015      -0.643
# Developer_United Game Artists                                               1.9116      1.043      1.832      0.067      -0.134       3.958
# Developer_Valhalla Game Studios                                            -4.0621      1.054     -3.852      0.000      -6.130      -1.995
# Developer_Valve Software                                                    1.1451      0.354      3.231      0.001       0.450       1.840
# Developer_Venom Games                                                      -3.0340      1.043     -2.910      0.004      -5.078      -0.990
# Developer_Vicarious Visions                                                 0.4830      0.197      2.447      0.014       0.096       0.870
# Developer_Villa Gorilla                                                     1.3241      0.373      3.552      0.000       0.593       2.055
# Developer_Visual Concepts                                                   0.6491      0.190      3.417      0.001       0.277       1.022
# Developer_Visual Impact                                                    -2.1159      0.493     -4.296      0.000      -3.082      -1.150
# Developer_Way Forward                                                       1.8442      1.041      1.771      0.077      -0.198       3.886
# Developer_WayForward Pocket Team                                           -2.1040      1.043     -2.018      0.044      -4.149      -0.059
# Developer_WhiteBear Studios                                                -5.2372      1.802     -2.907      0.004      -8.770      -1.705
# Developer_Yacht Club Games                                                  1.0130      0.373      2.714      0.007       0.281       1.745
# Developer_Yuke's                                                            0.8685      0.432      2.009      0.045       0.021       1.716
# Developer_ZeroDiv                                                          -2.0254      1.046     -1.936      0.053      -4.076       0.025
# Developer_Zoe Mode / HB Studios                                            -3.3037      1.042     -3.169      0.002      -5.347      -1.260
# Developer_Zombie Studios                                                   -1.7973      0.603     -2.979      0.003      -2.980      -0.614
# Developer_ZootFly                                                          -3.6087      1.043     -3.461      0.001      -5.653      -1.564
# Developer_n-Space                                                          -0.6644      0.324     -2.050      0.040      -1.300      -0.029
# ==============================================================================
# Omnibus:                      383.073   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              639.500
# Skew:                          -0.757   Prob(JB):                    1.36e-139
# Kurtosis:                       4.435   Cond. No.                     2.24e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.84e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# # Teste da regressão

# %%
score_teste= sm.add_constant(teste_score[dummy_score4])
y_previsto_score = dummy_score_4.predict(score_teste)

# %%
e = 0.10
teste_score = []
acertos_score = []
for previsao,real in zip(y_previsto_score,y_test_score):
    if previsao <= real + real*e and previsao >= real - real*e:

        acertos_score.append(1)

    teste_score.append(0)
    
acertos_score_ = ((len(acertos_score)/len(teste_score))*100)
print("A taxa de acertos foi de {0:.2f}%".format(acertos_score_))
# Out:
# A taxa de acertos foi de 48.94%

# %%
metrics.r2_score(y_test_score,y_previsto_score)
# Out:
# 0.14805805213607914
