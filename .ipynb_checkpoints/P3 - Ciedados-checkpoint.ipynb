# %%
# %matplotlib notebook
# %reset -f


import pandas as pd
import numpy as np
from scipy.stats import norm, probplot
import statsmodels.api as sm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from sklearn import preprocessing

### Função utilitária para fazer a regressão com constante adicionada
def regress(X,Y):
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    return results

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Fonte: 

dados = pd.read_excel("jogo.xlsx")

# %%
dados["Sales"] = dados["Global_Sales"].fillna(0) + dados["Total_Shipped"].fillna(0)
dados["Global_Sales"].fillna(0)
dados["Total_Shipped"].fillna(0)
# Out:
# 0        82.86
# 1        40.24
# 2        37.14
# 3        36.60
# 4        33.09
# 5        31.38
# 6        30.80
# 7        30.26
# 8        30.22
# 9        30.01
# 10       28.31
# 11       28.02
# 12       24.00
# 13       23.96
# 14       23.60
# 15       23.10
# 16       22.67
# 17       21.13
# 18       20.61
# 19        0.00
# 20        0.00
# 21       19.01
# 22       18.58
# 23       18.14
# 24       18.11
# 25       17.67
# 26       17.30
# 27       17.28
# 28       16.37
# 29       16.22
#          ...
# 55762     0.00
# 55763     0.00
# 55764     0.00
# 55765     0.00
# 55766     0.00
# 55767     0.00
# 55768     0.00
# 55769     0.00
# 55770     0.00
# 55771     0.00
# 55772     0.00
# 55773     0.00
# 55774     0.00
# 55775     0.00
# 55776     0.00
# 55777     0.00
# 55778     0.00
# 55779     0.00
# 55780     0.00
# 55781     0.00
# 55782     0.00
# 55783     0.00
# 55784     0.00
# 55785     0.00
# 55786     0.00
# 55787     0.00
# 55788     0.00
# ...

# %%
deletar = dados.loc[((dados.Global_Sales.fillna(0)) == 0) & ((dados.Total_Shipped.fillna(0)) == 0)]
a = deletar.index
dados.drop(a)
# Out:
#         Rank                                               Name  \
# 0          1                                         Wii Sports
# 1          2                                  Super Mario Bros.
# 2          3                                     Mario Kart Wii
# 3          4                      PlayerUnknown's Battlegrounds
# 4          5                                  Wii Sports Resort
# 5          6                 Pokemon Red / Green / Blue Version
# 6          7                              New Super Mario Bros.
# 7          8                                             Tetris
# 8          9                          New Super Mario Bros. Wii
# 9         10                                          Minecraft
# 10        11                                          Duck Hunt
# 11        12                                           Wii Play
# 12        13                                 Kinect Adventures!
# 13        14                                         Nintendogs
# ...

# %%
dados.columns
# Out:
# Index(['Rank', 'Name', 'basename', 'Genre', 'ESRB_Rating', 'Platform',
#        'Publisher', 'Developer', 'VGChartz_Score', 'Critic_Score',
#        'User_Score', 'Total_Shipped', 'Global_Sales', 'NA_Sales', 'PAL_Sales',
#        'JP_Sales', 'Other_Sales', 'Year', 'Last_Update', 'url', 'status',
#        'Vgchartzscore', 'img_url'],
#       dtype='object')

# %%
dados.Genre = dados.Genre.astype('category')
dados.ESRB_Rating = dados.ESRB_Rating.astype('category')
dados.Platform = dados.Platform.astype('category')
dados.Publisher = dados.Publisher.astype('category')
dados.Developer = dados.Developer.astype('category')

# %%
#a = dados.Genre.values
#print(a)

# %%
qualitativas = ['Genre', 'ESRB_Rating', 'Platform',
       'Publisher', 'Developer']
quantitativas = ['Rank', 'Name', 'basename','VGChartz_Score', 'Critic_Score',
       'User_Score', 'Total_Shipped', 'Global_Sales', 'NA_Sales', 'PAL_Sales',
       'JP_Sales', 'Other_Sales', 'Year', 'Last_Update','Vgchartzscore']

# %%
# Separaremos as preditoras
quant_x = quantitativas.copy()
quant_x.remove('SalePrice')
